# %% [markdown]
# <a href="https://colab.research.google.com/github/saeidsaadatigero/AI_ML_Computer-Vision/blob/main/31_Forward_%26Backward_Propagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# داده نمونه
X, y = make_moons(n_samples=500, noise=0.2, random_state=42)
y = y.reshape(1, -1)
X = X.T
m = X.shape[1]

# تابع‌های کمکی
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def relu(z):
    return np.maximum(0, z)

def relu_derivative(z):
    return z > 0

# مقداردهی اولیه
np.random.seed(42)
W1 = np.random.randn(4, 2) * 0.01
b1 = np.zeros((4, 1))
W2 = np.random.randn(1, 4) * 0.01
b2 = np.zeros((1, 1))

learning_rate = 0.5
epochs = 10000

for i in range(epochs):
    # Forward Propagation
    Z1 = np.dot(W1, X) + b1
    A1 = relu(Z1)
    Z2 = np.dot(W2, A1) + b2
    A2 = sigmoid(Z2)

    # Cost Function
    cost = -1/m * np.sum(y * np.log(A2 + 1e-8) + (1-y) * np.log(1-A2 + 1e-8))

    # Backward Propagation
    dZ2 = A2 - y
    dW2 = (1/m) * np.dot(dZ2, A1.T)
    db2 = (1/m) * np.sum(dZ2, axis=1, keepdims=True)
    dA1 = np.dot(W2.T, dZ2)
    dZ1 = dA1 * relu_derivative(Z1)
    dW1 = (1/m) * np.dot(dZ1, X.T)
    db1 = (1/m) * np.sum(dZ1, axis=1, keepdims=True)

    # Update weights
    W1 -= learning_rate * dW1
    b1 -= learning_rate * db1
    W2 -= learning_rate * dW2
    b2 -= learning_rate * db2

    # نمایش هزینه هر 1000 بار
    if i % 1000 == 0:
        print(f"Epoch {i} - Cost: {cost:.4f}")

# تست دقت
preds = (A2 > 0.5).astype(int)
accuracy = np.mean(preds == y)
print(f"\nAccuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 0 - Cost: 0.6932
# Epoch 1000 - Cost: 0.2797
# Epoch 2000 - Cost: 0.2797
# Epoch 3000 - Cost: 0.2797
# Epoch 4000 - Cost: 0.2797
# Epoch 5000 - Cost: 0.2797
# Epoch 6000 - Cost: 0.2797
# Epoch 7000 - Cost: 0.2797
# Epoch 8000 - Cost: 0.2797
# Epoch 9000 - Cost: 0.2797
#
# Accuracy: 86.00%
